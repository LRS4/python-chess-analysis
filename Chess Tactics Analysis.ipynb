# %% [markdown]
# ## Chess Tactics Analysis

# %% [markdown]
# Using requests and selenium to scrape data from my Chess.com and ChessTempo tactics records.

# %%
import numpy as np
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import requests
import csv
import datetime
import time

# %%
# use requests to get html source (Chess.com) with decorated URL
data = requests.get("https://www.chess.com/stats/puzzles/deadlyknightx").text

# %%
# scrape recent activity
recent = pd.read_html(data, attrs={'class':'table progress-table problems-table with-row-highlight'})[0]

# %%
# scrape tactic themes
motifs = pd.read_html(data, attrs={'class':'progress-table'})[0]

# %%
import os  
from selenium import webdriver  
from selenium.webdriver.common.keys import Keys  
from selenium.webdriver.chrome.options import Options 

options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

# %%
# use selenium to login to chesstempo.com
driver = webdriver.Chrome("chromedriver.exe", options=options)
driver.get("https://chesstempo.com/chess-statistics.html")
driver.find_element_by_id("usernameField").send_keys("USERNAME") # send username
driver.find_element_by_id("passwordField").send_keys("PASSWORD") # send password
driver.find_element_by_id("loginButton").click()
time.sleep(10)

# scrape table
page_1 = pd.read_html(driver.page_source)[2]

# click next
time.sleep(5)
driver.find_element_by_id("yui-pg0-0-next-link").click()
time.sleep(5)

# scrape table
page_2 = pd.read_html(driver.page_source)[2]

# close browser
driver.close()

# %%
# combine data from both pages
ctempo = page_1.append(page_2, ignore_index=True)

# %% [markdown]
# ### Data Transformation - Chess.com

# %%
recent.head()
# Out:
#           Date      ID  Rating Moves Target Time My Time Avg Time  \
# 0  Sep 7, 2019  742186    1616   3/3        0:36    1:49     0:34
# 1  Sep 7, 2019  768668    1490   3/3        0:31   13:59     0:58
# 2  Sep 7, 2019  497058    1761   1/4        0:51    1:37     1:10
# 3  Sep 7, 2019  606100    1923   5/5        1:08    2:35     1:33
# 4  Sep 7, 2019  703298    1326   3/3        0:26    3:06     0:53
#
#         Outcome  My Rating
# 0   (80% |  +7)       1627
# 1   (70% |  +3)       1620
# 2   (23% |  -5)       1617
# 3  (87% |  +14)       1622
# 4   (70% |  +2)       1608

# %%
# replace the (  |  ) in the Outcome column
recent['Outcome'] = recent['Outcome'].str.replace('(','').str.replace(')','').str.replace('|','')

# %%
# split columns - create white player, black player, white rating, black rating
new = recent.Outcome.str.split(" ", n=2, expand=True)

# %%
# add back to dataframe
recent['Outcome'] = new[2]
recent['Outcome %'] = new[0].str.replace('%','').astype(int)

# %%
recent.head()
# Out:
#           Date      ID  Rating Moves Target Time My Time Avg Time Outcome  \
# 0  Sep 7, 2019  742186    1616   3/3        0:36    1:49     0:34      +7
# 1  Sep 7, 2019  768668    1490   3/3        0:31   13:59     0:58      +3
# 2  Sep 7, 2019  497058    1761   1/4        0:51    1:37     1:10      -5
# 3  Sep 7, 2019  606100    1923   5/5        1:08    2:35     1:33     +14
# 4  Sep 7, 2019  703298    1326   3/3        0:26    3:06     0:53      +2
#
#    My Rating  Outcome %
# 0       1627         80
# 1       1620         70
# 2       1617         23
# 3       1622         87
# 4       1608         70

# %%
recent['Outcome'] = recent['Outcome'].str.replace(' ', '')

# %%
motifs.head()
# Out:
#               Category Score  \
# 0          Bishop Pair   90%
# 1       Knight Outpost   79%
# 2             Windmill   76%
# 3       Underpromotion   76%
# 4  Two Rooks Checkmate   70%
#
#                                           Unnamed: 2
# 0  Bishop Pair  Attempts: 3  Passed: 3  Failed: 0...
# 1  Knight Outpost  Attempts: 2  Passed: 2  Failed...
# 2  Windmill  Attempts: 6  Passed: 5  Failed: 1  A...
# 3  Underpromotion  Attempts: 3  Passed: 2  Failed...
# 4  Two Rooks Checkmate  Attempts: 1  Passed: 1  F...

# %%
# split into attempts, passed, failed, avg score
new = motifs['Unnamed: 2'].str.split('Attempts: ', expand=True)
new = new[1].str.split('Passed: ', expand=True)
motifs['Attempts'] = new[0]

# %%
new = new[1].str.split('Failed: ', expand=True)
motifs['Passed'] = new[0]

new = new[1].str.split('Avg Score: ', expand=True)
motifs['Failed'] = new[0]

# %%
motifs['Avg Score %'] = new[1]

# %%
motifs.head()
# Out:
#               Category Score  \
# 0          Bishop Pair   90%
# 1       Knight Outpost   79%
# 2             Windmill   76%
# 3       Underpromotion   76%
# 4  Two Rooks Checkmate   70%
#
#                                           Unnamed: 2 Attempts Passed Failed  \
# 0  Bishop Pair  Attempts: 3  Passed: 3  Failed: 0...      3      3      0
# 1  Knight Outpost  Attempts: 2  Passed: 2  Failed...      2      2      0
# 2  Windmill  Attempts: 6  Passed: 5  Failed: 1  A...      6      5      1
# 3  Underpromotion  Attempts: 3  Passed: 2  Failed...      3      2      1
# 4  Two Rooks Checkmate  Attempts: 1  Passed: 1  F...      1      1      0
#
#   Avg Score %
# 0       90.00
# 1       78.50
# 2       76.17
# 3       75.67
# 4       70.00

# %%
motifs = motifs.drop(['Unnamed: 2'], axis=1)

# %% [markdown]
# ### Data Transformation - ChessTempo

# %%
ctempo['User Rating'] = ctempo['User Rating'].str.replace('(','').str.replace(')','')

# %%
new = ctempo['User Rating'].str.split(' ', expand=True)
ctempo['User Rating'] = new[0]
ctempo['Outcome'] = new[1]

# %% [markdown]
# ### Add Calculated Columns

# %%
# add pass or fail to recent
pf = np.array([])

for i in recent['Outcome']:
    if "+" in i:
        pf = np.append(pf, "Pass")
    else:
        pf = np.append(pf, "Fail")

# %%
recent['P/F'] = pf

# %%
recent.head()
# Out:
#           Date      ID  Rating Moves Target Time My Time Avg Time Outcome  \
# 0  Sep 7, 2019  742186    1616   3/3        0:36    1:49     0:34      +7
# 1  Sep 7, 2019  768668    1490   3/3        0:31   13:59     0:58      +3
# 2  Sep 7, 2019  497058    1761   1/4        0:51    1:37     1:10      -5
# 3  Sep 7, 2019  606100    1923   5/5        1:08    2:35     1:33     +14
# 4  Sep 7, 2019  703298    1326   3/3        0:26    3:06     0:53      +2
#
#    My Rating  Outcome %   P/F
# 0       1627         80  Pass
# 1       1620         70  Pass
# 2       1617         23  Fail
# 3       1622         87  Pass
# 4       1608         70  Pass

# %%
# add pass or fail to ctempo
pf = np.array([])

for i in ctempo['Outcome']:
    if '+' in i:
        pf = np.append(pf, "Pass")
    else:
        pf = np.append(pf, "Fail")

# %%
ctempo['P/F'] = pf

# %%
# add chess.com problem URLS
urls = np.array([])

for i in recent['ID']:
    urls = np.append(urls, "https://www.chess.com/puzzles/problem/" + str(i))

# %%
recent['URL'] = urls

# %%
# add chess tempo problem URLS
ct_urls = np.array([])

for i in ctempo['ProblemId']:
    ct_urls = np.append(ct_urls, "https://chesstempo.com/chess-problems/" + str(i))

# %%
ctempo['URL'] = ct_urls

# %%
recent.head()
# Out:
#           Date      ID  Rating Moves Target Time My Time Avg Time Outcome  \
# 0  Sep 7, 2019  742186    1616   3/3        0:36    1:49     0:34      +7
# 1  Sep 7, 2019  768668    1490   3/3        0:31   13:59     0:58      +3
# 2  Sep 7, 2019  497058    1761   1/4        0:51    1:37     1:10      -5
# 3  Sep 7, 2019  606100    1923   5/5        1:08    2:35     1:33     +14
# 4  Sep 7, 2019  703298    1326   3/3        0:26    3:06     0:53      +2
#
#    My Rating  Outcome %   P/F                                           URL
# 0       1627         80  Pass  https://www.chess.com/puzzles/problem/742186
# 1       1620         70  Pass  https://www.chess.com/puzzles/problem/768668
# 2       1617         23  Fail  https://www.chess.com/puzzles/problem/497058
# 3       1622         87  Pass  https://www.chess.com/puzzles/problem/606100
# 4       1608         70  Pass  https://www.chess.com/puzzles/problem/703298

# %%
ctempo.head()
# Out:
#    #                 Time  ProblemId  Rating      Type Av Time Solve Time  \
# 0  1  2019-09-07 11:23:28      53947  1374.2  Standard   02:31      03:38
# 1  2  2019-09-07 11:19:46      92238  1417.5  Standard   01:53      00:45
# 2  3  2019-09-07 11:18:57     173690  1296.2  Standard   01:33      00:37
# 3  4  2019-09-07 11:17:48      23857  1599.4  Standard   03:32      01:18
# 4  5  2019-09-07 11:16:14      45302  1431.7  Standard   02:03      04:25
#
#   After First User Rating Outcome   P/F  \
# 0       01:19      1569.5    +1.8  Pass
# 1       00:03      1567.6    +2.3  Pass
# 2       00:02      1565.3    +1.4  Pass
# 3       00:00      1563.9    -3.7  Fail
# 4       00:04      1567.6    +2.7  Pass
#
#                                             URL
# 0   https://chesstempo.com/chess-problems/53947
# 1   https://chesstempo.com/chess-problems/92238
# 2  https://chesstempo.com/chess-problems/173690
# 3   https://chesstempo.com/chess-problems/23857
# 4   https://chesstempo.com/chess-problems/45302

# %% [markdown]
# ### Export to CSV

# %%
# export to CSV file - to be used as Power BI data model
ctempo.to_csv(r"C:\Users\lrspe\Dropbox\Data Science\Chess\chessTempo.csv")
recent.to_csv(r"C:\Users\lrspe\Dropbox\Data Science\Chess\chessTactics.csv")
motifs.to_csv(r"C:\Users\lrspe\Dropbox\Data Science\Chess\chessMotifs.csv")
